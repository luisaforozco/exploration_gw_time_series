# %% [markdown]
# # Exploration of BRO REST API
# - [Documentation - BRO productomgeving](https://www.bro-productomgeving.nl/bpo/latest/url-s-publieke-rest-services)
# - [REST API documentation](https://publiek.broservices.nl/gm/gld/v1/swagger-ui/)

# %%
import requests
headers = {
    "accept": "text/plain"
}

# %%
GLD_ID = "GLD000000054694" # BRO-ID
response = requests.get(f"https://publiek.broservices.nl/gm/gld/v1/seriesAsCsv/{GLD_ID}", headers=headers)

# %% [markdown]
# The response is plain text of csv data of the time series.

# %%
response.text
# Out:
# 'Tijdstip,Voorlopige Waarde [m],Voorlopige Opmerking,Beoordeelde Waarde [m],Beoordeelde Opmerking,Controle Waarde [m],Controle Opmerking,Onbekend Waarde [m],Onbekend Opmerking\n-543243600000,,,,,,,0.110,\n-537541200000,,,,,,,0.110,\n-534085200000,,,,,,,0.110,\n-532616400000,,,,,,,0.050,\n-531234000000,,,,,,,-0.220,\n-530197200000,,,,,,,-0.330,\n-528987600000,,,,,,,-0.750,\n-527518800000,,,,,,,-0.050,\n-526309200000,,,,,,,-0.500,\n-524926800000,,,,,,,-0.680,\n-523717200000,,,,,,,-0.770,\n-522162000000,,,,,,,-0.600,\n-520952400000,,,,,,,-0.780,\n-519656400000,,,,,,,-0.880,\n-518360400000,,,,,,,-0.600,\n-516978000000,,,,,,,-0.980,\n-515768400000,,,,,,,-0.470,\n-514299600000,,,,,,,-0.370,\n-513090000000,,,,,,,-0.110,\n-511707600000,,,,,,,-0.510,\n-510498000000,,,,,,,-0.630,\n-509029200000,,,,,,,-0.440,\n-507819600000,,,,,,,-0.370,\n-506437200000,,,,,,,-0.360,\n-505227600000,,,,,,,0.150,\n-503758800000,,,,,,,0.150,\n-500994000000,,,,,,,-0.560,\n-499784400000,,,,,,,0.040,\n-498574800000,,,,,,,-0.140,\n-497365200000,,,,,,,-0.020,\n-495982800000,,,,,,,-0.350,\n-494773200000,,,,,,,-0.510,\n-493390800000,,,,,,,-0.640,\n-492181200000,,,,,,,-0.600,\n-490712400000,,,,,,,-0.930,\n-489502800000,,,,,,,-1.080,\n-488120400000,,,,,,,-0.930,\n-486910800000,,,,,,,-0.350,\n-485269200000,,,,,,,-0.050,\n-484232400000,,,,,,,-0.150,\n-482763600000,,,,,,,-0.310,\n-481554000000,,,,,,,0.230,\n-480171600000,,,,,,,0.220,\n-478962000000,,,,,,,0.220,\n-477406800000,,,,,,,0.200,\n-476197200000,,,,,,,0.270,\n-474901200000,,,,,,,0.240,\n-473691600000,,,,,,,0.190,\n-471013200000,,,,,,,0.270,\n-469544400000,,,,,,,0.170,\n-467125200000,,,,,,,0.170,\n-464446800000,,,,,,,-0.210,\n-463237200000,,,,,,,-0.460,\n-461854800000,,,,,,,-0.400,\n-460645200000,,,,,,,-0.330,\n-459176400000,,,,,,,-0.470,\n-457966800000,,,,,,,-0.610,\n-456584400000,,,,,,,-0.780,\n-455374800000,,,,,,,-1.200,\n-453646800000,,,,,,,-1.250,\n-452610000000,,,,,,,-1.250,\n-451227600000,,,,,,,-1.260,\n-450018000000,,,,,,,-0.910,\n-448635600000,,,,,,,-0.340,\n-447426000000,,,,,,,0.270,\n-445957200000,,,,,,,0.060,\n-444747600000,,,,,,,0.180,\n-443365200000,,,,,,,0.050,\n-442155600000,,,,,,,0.270,\n-440686800000,,,,,,,0.270,\n-435502800000,,,,,,,0.040,\n-434293200000,,,,,,,-0.040,\n-432824400000,,,,,,,-0.350,\n-431614800000,,,,,,,-0.600,\n-430232400000,,,,,,,-0.640,\n-429022800000,,,,,,,-0.540,\n-427554000000,,,,,,,-0.560,\n-426344400000,,,,,,,-0.700,\n-424962000000,,,,,,,-0.790,\n-423752400000,,,,,,,-0.910,\n-422283600000,,,,,,,-0.380,\n-421074000000,,,,,,,0.170,\n-419605200000,,,,,,,0.040,\n-418395600000,,,,,,,-0.150,\n-416926800000,,,,,,,-0.040,\n-415717200000,,,,,,,0.270,\n-414334800000,,,,,,,0.110,\n-413125200000,,,,,,,0.270,\n-411742800000,,,,,,,0.270,\n-410533200000,,,,,,,-0.210,\n-409064400000,,,,,,,0.180,\n-407854800000,,,,,,,0.170,\n-406386000000,,,,,,,0.270,\n-405176400000,,,,,,,-0.160,\n-403966800000,,,,,,,-0.220,\n-402757200000,,,,,,,-0.270,\n-401202000000,,,,,,,-0.480,\n-399992400000,,,,,,,-0.610,\n-398696400000,,,,,,,-0.660,\n-397314000000,,,,,,,-0.820,\n-396018000000,,,,,,,-0.850,\n-394808400000,,,,,,,-1.160,\n-393339600000,,,,,,,-1.050,\n-392130000000,,,,,,,-0.970,\n-390747600000,,,,,,,-0.190,\n-389538000000,,,,,,,0.150,\n-388069200000,,,,,,,0.270,\n-386859600000,,,,,,,0.140,\n-385477200000,,,,,,,-0.170,\n-384267600000,,,,,,,0.270,\n-382798800000,,,,,,,0.100,\n-381589200000,,,,,,,0.150,\n-380206800000,,,,,,,0.080,\n-378997200000,,,,,,,0.080,\n-377528400000,,,,,,,0.200,\n-376318800000,,,,,,,0.180,\n-374850000000,,,,,,,0.270,\n-373640400000,,,,,,,0.030,\n-372430800000,,,,,,,0.020,\n-371221200000,,,,,,,-0.040,\n-369752400000,,,,,,,-0.330,\n-368542800000,,,,,,,-0.200,\n-367160400000,,,,,,,-0.580,\n-365950800000,,,,,,,-0.560,\n-364482000000,,,,,,,-0.710,\n-363272400000,,,,,,,-0.590,\n-361890000000,,,,,,,-0.630,\n-360680400000,,,,,,,-0.250,\n-359211600000,,,,,,,0.190,\n-358002000000,,,,,,,-0.090,\n-356446800000,,,,,,,-0.150,\n-355237200000,,,,,,,-0.010,\n-353941200000,,,,,,,0.110,\n-352731600000, ...

# %% [markdown]
# We can put the contents of the response in a pandas dataframe. Empty values are going to be `NaN`.
# The columns and format of this file is different than the csv that one could download from the portal.

# %%
import pandas as pd
from io import StringIO

# %%
df = pd.read_csv(StringIO(response.text))

# %%
df
# Out:
#          Tijdstip  Voorlopige Waarde [m]  Voorlopige Opmerking  \
# 0   -543243600000                    NaN                   NaN
# 1   -537541200000                    NaN                   NaN
# 2   -534085200000                    NaN                   NaN
# 3   -532616400000                    NaN                   NaN
# 4   -531234000000                    NaN                   NaN
# ..            ...                    ...                   ...
# 261 -171291600000                    NaN                   NaN
# 262 -169822800000                    NaN                   NaN
# 263 -168613200000                    NaN                   NaN
# 264 -167144400000                    NaN                   NaN
# 265 -165934800000                    NaN                   NaN
#
#      Beoordeelde Waarde [m]  Beoordeelde Opmerking  Controle Waarde [m]  \
# 0                       NaN                    NaN                  NaN
# 1                       NaN                    NaN                  NaN
# 2                       NaN                    NaN                  NaN
# 3                       NaN                    NaN                  NaN
# 4                       NaN                    NaN                  NaN
# ..                      ...                    ...                  ...
# 261                     NaN                    NaN                  NaN
# 262                     NaN                    NaN                  NaN
# 263                     NaN                    NaN                  NaN
# 264                     NaN                    NaN                  NaN
# 265                     NaN                    NaN                  NaN
#
#      Controle Opmerking  Onbekend Waarde [m]      Onbekend Opmerking
# 0                   NaN                 0.11                     NaN
# 1                   NaN                 0.11                     NaN
# 2                   NaN                 0.11                     NaN
# 3                   NaN                 0.05                     NaN
# 4                   NaN                -0.22                     NaN
# ..                  ...                  ...                     ...
# 261                 NaN                -0.90                     NaN
# 262                 NaN                -1.06                     NaN
# 263                 NaN                  NaN  kleinerDanLimietwaarde
# 264                 NaN                  NaN  kleinerDanLimietwaarde
# 265                 NaN                  NaN  kleinerDanLimietwaarde
#
# [266 rows x 9 columns]

# %%
# remove columns whose name contains "Opmerking" (case-insensitive)
mask = df.columns.str.contains(r'Opmerking', case=False, na=False)
# remove columns containing NaNs
df_clean = df.loc[:, ~mask].dropna(axis=1, how='all')
# remove columns that contain Nans
df_clean.dropna(inplace=True)

# %%
df_clean
# Out:
#          Tijdstip  Onbekend Waarde [m]
# 0   -543243600000                 0.11
# 1   -537541200000                 0.11
# 2   -534085200000                 0.11
# 3   -532616400000                 0.05
# 4   -531234000000                -0.22
# ..            ...                  ...
# 258 -175093200000                -0.60
# 259 -173797200000                -0.78
# 260 -172501200000                -0.82
# 261 -171291600000                -0.90
# 262 -169822800000                -1.06
#
# [260 rows x 2 columns]
